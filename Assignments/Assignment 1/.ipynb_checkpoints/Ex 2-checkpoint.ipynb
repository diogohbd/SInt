# %% [markdown]
# ## Importing Tools

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from pyfume.Clustering import Clusterer
from pyfume.EstimateAntecendentSet import AntecedentEstimator
from pyfume.EstimateConsequentParameters import ConsequentEstimator
from pyfume.SimpfulModelBuilder import SugenoFISBuilder
from pyfume.Tester import SugenoFISTester
from pandas import read_csv 
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error, explained_variance_score
import matplotlib.pyplot as plt

# %% [markdown]
# ## Pre-processing Data

# %%
data = pd.read_csv('./data/hairdryer.csv',header=None)
indexes = ['inVolt', 'outTemp']
data.columns = indexes
data.head()
indexes = indexes[:-1]

# %%
dataX = data.drop('outTemp', axis = 1)
dataY = data.outTemp

xTrain, xTest, yTrain, yTest = train_test_split(dataX, dataY, test_size = 0.3, random_state=0)

xTrain = xTrain.to_numpy()
xTest = xTest.to_numpy()
yTrain = yTrain.array
yTest = yTest.array

# %%
plt.scatter(dataX, dataY)
plt.xlabel('Voltage (input)')  
plt.ylabel('Temperature (output)')  
plt.show()

# %% [markdown]
# ## Building the model

# %% [markdown]
# #### FCM

# %%
mseArray1 = []
mapeArray1 = []
varArray1 = []
for clustNum in range(2, 50):
    clusters = Clusterer(x_train=xTrain, y_train=yTrain, nr_clus=clustNum)
        
    clustCenters, partMatrix, _ = clusters.cluster(method='fcm')
        
    antEst = AntecedentEstimator(xTrain, partMatrix)
    antParams = antEst.determineMF()
        
    conseqEst = ConsequentEstimator(xTrain, yTrain, partMatrix)
    conseqParams = conseqEst.suglms()
        
    # Build first-order Takagi-Sugeno model
    modbuilder = SugenoFISBuilder(antParams, conseqParams, indexes, save_simpful_code=False)
    model = modbuilder.get_model()
        
    # Get model predictions
    modtester = SugenoFISTester(model, xTest, indexes)
    yPrediction = modtester.predict()[0]

    mse = mean_squared_error(yTest, yPrediction)
    mape = mean_absolute_percentage_error(yTest, yPrediction)
    var = explained_variance_score(yTest, yPrediction)
    mseArray1.append(mse)
    mapeArray1.append(mape)
    varArray1.append(var)
# Out:
#  * Detected 2 rules / clusters
#  * Detected Sugeno model type
#  * Detected 3 rules / clusters
#  * Detected Sugeno model type
#  * Detected 4 rules / clusters
#  * Detected Sugeno model type
#  * Detected 5 rules / clusters
#  * Detected Sugeno model type
#  * Detected 6 rules / clusters
#  * Detected Sugeno model type
#  * Detected 7 rules / clusters
#  * Detected Sugeno model type
#  * Detected 8 rules / clusters
#  * Detected Sugeno model type
#  * Detected 9 rules / clusters
#  * Detected Sugeno model type
#  * Detected 10 rules / clusters
#  * Detected Sugeno model type
#  * Detected 11 rules / clusters
#  * Detected Sugeno model type
#  * Detected 12 rules / clusters
#  * Detected Sugeno model type
#  * Detected 13 rules / clusters
#  * Detected Sugeno model type
#  * Detected 14 rules / clusters
#  * Detected Sugeno model type
#  * Detected 15 rules / clusters
#  * Detected Sugeno model type
#  * Detected 16 rules / clusters
#  * Detected Sugeno model type
#  * Detected 17 rules / clusters
#  * Detected Sugeno model type
#  * Detected 18 rules / clusters
#  * Detected Sugeno model type
#  * Detected 19 rules / clusters
#  * Detected Sugeno model type
#  * Detected 20 rules / clusters
#  * Detected Sugeno model type
#  * Detected 21 rules / clusters
#  * Detected Sugeno model type
#  * Detected 22 rules / clusters
#  * Detected Sugeno model type
#  * Detected 23 rules / clusters
#  * Detected Sugeno model type
#  * Detected 24 rules / clusters
#  * Detected Sugeno model type
#  * Detected 25 rules / clusters
#  * Detected Sugeno model type
#  * Detected 26 rules / clusters
#  * Detected Sugeno model type
#  * Detected 27 rules / clusters
#  * Detected Sugeno model type
#  * Detected 28 rules / clusters
#  * Detected Sugeno model type
#  * Detected 29 rules / clusters
#  * Detected Sugeno model type
#  * Detected 30 rules / clusters
#  * Detected Sugeno model type
#  * Detected 31 rules / clusters
#  * Detected Sugeno model type
#  * Detected 32 rules / clusters
#  * Detected Sugeno model type
#  * Detected 33 rules / clusters
#  * Detected Sugeno model type
#  * Detected 34 rules / clusters
#  * Detected Sugeno model type
#  * Detected 35 rules / clusters
#  * Detected Sugeno model type
#  * Detected 36 rules / clusters
#  * Detected Sugeno model type
#  * Detected 37 rules / clusters
#  * Detected Sugeno model type
#  * Detected 38 rules / clusters
#  * Detected Sugeno model type
#  * Detected 39 rules / clusters
#  * Detected Sugeno model type
#  * Detected 40 rules / clusters
#  * Detected Sugeno model type
#  * Detected 41 rules / clusters
#  * Detected Sugeno model type
#  * Detected 42 rules / clusters
#  * Detected Sugeno model type
#  * Detected 43 rules / clusters
#  * Detected Sugeno model type
#  * Detected 44 rules / clusters
#  * Detected Sugeno model type
#  * Detected 45 rules / clusters
#  * Detected Sugeno model type
#  * Detected 46 rules / clusters
#  * Detected Sugeno model type
#  * Detected 47 rules / clusters
#  * Detected Sugeno model type
#  * Detected 48 rules / clusters
#  * Detected Sugeno model type
#  * Detected 49 rules / clusters
#  * Detected Sugeno model type

# %% [markdown]
# #### GK

# %%
mseArray2 = []
mapeArray2 = []
varArray2 = []
for clustNum in range(2, 50):
    clusters = Clusterer(x_train=xTrain, y_train=yTrain, nr_clus=clustNum)
        
    clustCenters, partMatrix, _ = clusters.cluster(method='gk')
        
    antEst = AntecedentEstimator(xTrain, partMatrix)
    antParams = antEst.determineMF()
        
    conseqEst = ConsequentEstimator(xTrain, yTrain, partMatrix)
    conseqParams = conseqEst.suglms()
        
    # Build first-order Takagi-Sugeno model
    modbuilder = SugenoFISBuilder(antParams, conseqParams, indexes, save_simpful_code=False)
    model = modbuilder.get_model()
        
    # Get model predictions
    modtester = SugenoFISTester(model, xTest, indexes)
    yPrediction = modtester.predict()[0]

    mse = mean_absolute_percentage_error(yTest, yPrediction)
    mape = mean_absolute_percentage_error(yTest, yPrediction)
    var = explained_variance_score(yTest, yPrediction)
    mseArray2.append(mse)
    mapeArray2.append(mape)
    varArray2.append(var)
# Out:
#  * Detected 2 rules / clusters
#  * Detected Sugeno model type
#  * Detected 3 rules / clusters
#  * Detected Sugeno model type
#  * Detected 4 rules / clusters
#  * Detected Sugeno model type
#  * Detected 5 rules / clusters
#  * Detected Sugeno model type
#  * Detected 6 rules / clusters
#  * Detected Sugeno model type
#  * Detected 7 rules / clusters
#  * Detected Sugeno model type
#  * Detected 8 rules / clusters
#  * Detected Sugeno model type
#  * Detected 9 rules / clusters
#  * Detected Sugeno model type
#  * Detected 10 rules / clusters
#  * Detected Sugeno model type
#  * Detected 11 rules / clusters
#  * Detected Sugeno model type
#  * Detected 12 rules / clusters
#  * Detected Sugeno model type
#  * Detected 13 rules / clusters
#  * Detected Sugeno model type
#  * Detected 14 rules / clusters
#  * Detected Sugeno model type
#  * Detected 15 rules / clusters
#  * Detected Sugeno model type
#  * Detected 16 rules / clusters
#  * Detected Sugeno model type
#  * Detected 17 rules / clusters
#  * Detected Sugeno model type
#  * Detected 18 rules / clusters
#  * Detected Sugeno model type
#  * Detected 19 rules / clusters
#  * Detected Sugeno model type
#  * Detected 20 rules / clusters
#  * Detected Sugeno model type
#  * Detected 21 rules / clusters
#  * Detected Sugeno model type
#  * Detected 22 rules / clusters
#  * Detected Sugeno model type
#  * Detected 23 rules / clusters
#  * Detected Sugeno model type
#  * Detected 24 rules / clusters
#  * Detected Sugeno model type
#  * Detected 25 rules / clusters
#  * Detected Sugeno model type
#  * Detected 26 rules / clusters
#  * Detected Sugeno model type
#  * Detected 27 rules / clusters
#  * Detected Sugeno model type
#  * Detected 28 rules / clusters
#  * Detected Sugeno model type
#  * Detected 29 rules / clusters
#  * Detected Sugeno model type
#  * Detected 30 rules / clusters
#  * Detected Sugeno model type
#  * Detected 31 rules / clusters
#  * Detected Sugeno model type
#  * Detected 32 rules / clusters
#  * Detected Sugeno model type
#  * Detected 33 rules / clusters
#  * Detected Sugeno model type
#  * Detected 34 rules / clusters
#  * Detected Sugeno model type
#  * Detected 35 rules / clusters
#  * Detected Sugeno model type
#  * Detected 36 rules / clusters
#  * Detected Sugeno model type
#  * Detected 37 rules / clusters
#  * Detected Sugeno model type
#  * Detected 38 rules / clusters
#  * Detected Sugeno model type
#  * Detected 39 rules / clusters
#  * Detected Sugeno model type
#  * Detected 40 rules / clusters
#  * Detected Sugeno model type
#  * Detected 41 rules / clusters
#  * Detected Sugeno model type
#  * Detected 42 rules / clusters
#  * Detected Sugeno model type
#  * Detected 43 rules / clusters
#  * Detected Sugeno model type
#  * Detected 44 rules / clusters
#  * Detected Sugeno model type
#  * Detected 45 rules / clusters
#  * Detected Sugeno model type
#  * Detected 46 rules / clusters
#  * Detected Sugeno model type
#  * Detected 47 rules / clusters
#  * Detected Sugeno model type
#  * Detected 48 rules / clusters
#  * Detected Sugeno model type
#  * Detected 49 rules / clusters
#  * Detected Sugeno model type

# %% [markdown]
# ## Plot results

# %%
plt.plot(range(2,50), mseArray1, label="FCM", color="blue", marker="o")
plt.plot(range(2,50), mseArray2, label="GK", color="red", marker="o",)
plt.xlabel("Clusters")
plt.ylabel("MSE")
plt.title("MSE")
plt.legend()
plt.show()

# %%
plt.plot(range(2,50), mapeArray1, label="FCM", color="blue", marker="o")
plt.plot(range(2,50), mapeArray2, label="GK", color="red", marker="o",)
plt.xlabel("Clusters")
plt.ylabel("MAPE")
plt.title("MAPE")
plt.legend()
plt.show()

# %%
plt.plot(range(2,50), mapeArray1, label="FCM", color="blue", marker="o")
plt.plot(range(2,50), vaArray2, label="GK", color="red", marker="o",)
plt.xlabel("Clusters")
plt.ylabel("Var")
plt.title("Var")
plt.legend()
plt.show()
